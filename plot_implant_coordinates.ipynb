# %%
from rat_brain_atlas_api import plot_implant_coords

# %matplotlib widget

# %%
# Test: AP= -3.5 mm, ML= 2.8 mm, DV= 2.0 mm; 30 degree rotation about DV axis
s_comb_bot, s_comb_top = plot_implant_coords(
    AP=-3.6,
    ML=2.8,
    DV=2.0,
    angle=30,
    span=750,        # microns
    skull_t=600,     # microns
    plot_radius=8    # pixel radius for markers
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
